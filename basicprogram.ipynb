# %%
print('Hello World')
# Out:
# Hello World

# %%
name=input()
age=int(input())
print(f'my name is {name} and my age is {age}')
# Out:
# my name is nani and my age is 12

# %%
a=12
b=56
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 68
# -44
# 672
# 0.21428571428571427

# %%
a=90
b=80
a,b=b,a
print(a,b)
# Out:
# 80 90

# %%
n=int(input())
print(n**2)
print(n**3)
# Out:
# 9
# 27

# %%
list1=[1,2,3,4,5]
greater=list1[0]
for i in list1:
    if i>greater:
        greater=i
print(greater)
# Out:
# 5

# %%
list2=[10,20,30,40,50]
list2.append(60)
list2.pop(2)
list2.reverse()
print(list2)
# Out:
# [60, 50, 40, 20, 10]

# %%
numbers = [1, 2, 3, 4, 5]
summ=0
for i in numbers:
    summ+=i
print(summ)
# Out:
# 15

# %%
list1=[1,2,3,4,5]
for i in list1:
    if i%2==0:
        print(i)
# Out:
# 2
# 4

# %%
t=(1,2,3,4,5)
print(t)
# Out:
# (1, 2, 3, 4, 5)

# %%
t1=(10,20,30,40,50)
print(t1[0:3])
# Out:
# (10, 20, 30)

# %%
colors = ("red", "green", "blue", "yellow")
print(len(colors))
# Out:
# 4

# %%
fruits = ("apple", "banana", "mango")
if 'apple' in fruits:
    print("apple is present")
# Out:
# apple is present

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]
print(set(numbers))
# Out:
# {1, 2, 3, 4, 5}

# %%
colors = {"red", "blue", "green"}
colors.add('pink')
print(colors)
# Out:
# {'pink', 'blue', 'red', 'green'}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
print(set1&set2)
print(set1|set2)
print(set1-set2)
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}

# %%
student = {
    "name": "Ravi",
    "age": 20,
    "course": "Python"
}
print(student['age'])
# Out:
# 20

# %%
student = {
    "name": "Ravi",
    "age": 20
}
student['course'] = 'Python'
print(student)
# Out:
# {'name': 'Ravi', 'age': 20, 'course': 'Python'}

# %%
marks = {
    "Math": 80,
    "Science": 75,
    "English": 90
}
total_marks = sum(marks.values())
print(total_marks)
# Out:
# 245

# %%
list1=[1,23,4,5]
total=0
for i in list1:
    total+=i
print(total)
# Out:
# 33

# %%
dict1={
    'name':['rebu','pori','kanni'],
    'age':[12,34,56]
}
print(dict1.values())
print(dict1.keys())
print(dict1.items())
# for i in dict1.keys():
#     print(i)
print(dict1['name'])
print(dict1['age'])
dict1['marks']=[67,78,90]
print(dict1)
# Out:
# dict_values([['rebu', 'pori', 'kanni'], [12, 34, 56]])
# dict_keys(['name', 'age'])
# dict_items([('name', ['rebu', 'pori', 'kanni']), ('age', [12, 34, 56])])
# ['rebu', 'pori', 'kanni']
# [12, 34, 56]
# {'name': ['rebu', 'pori', 'kanni'], 'age': [12, 34, 56], 'marks': [67, 78, 90]}

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.11.9' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
