# %%
try:
    a=int(input())
    b=int(input())
    c=a/b
    print(c)
except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError:
    print("Please enter a non-zero value for the denominator.")
# Out:
# Please enter a non-zero value for the denominator.

# %%
try:
    num=int(input())

except ValueError:
    print("Please enter a valid integer.")
# Out:
# Please enter a valid integer.

# %%
try:
    numbers = [10, 20, 30, 40]
    print(numbers[6])
except IndexError:
    print("Index out of range.")
# Out:
# Index out of range.

# %%
try:
    with open('file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("The file was not found.")
# Out:
# The file was not found.

# %%
try:
    a=int(input())
    if a>100:
        raise ValueError("Value must be less than or equal to 100.")
except ValueError as e:
    print(e)
# Out:
# Value must be less than or equal to 100.

# %%
a=int(input())
if a>200:
    raise ValueError("Value must be less than or equal to 200.")
else:
    print("Value is acceptable.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 a=int(input())
#       2 if a>200:
# ----> 3     raise ValueError("Value must be less than or equal to 200.")
#       4 else:
#       5     print("Value is acceptable.")
#
# ValueError: Value must be less than or equal to 200.
