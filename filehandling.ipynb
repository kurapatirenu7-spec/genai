# %%
file=open(r"D:\ file.txt",'r')
data=file.read()
print(data)
file.close()
# Out:
# this the new line hereHello, world!Hello, world!

# %%
file=open(r"D:\ file.txt",'w')
data=file.write('hi im inside the file tq u')
print(data)
file.close()
print('data has been entered sucessfully')
# Out:
# 26
# data has been entered sucessfully

# %%
file=open(r"D:\ file.txt",'a')
file.write('101,200,john')
# Out:
# 12

# %%
with open(r"D:\ file.txt",'r') as file:
    data=file.read()
    print(data)
# Out:
# hi im inside the file tq u101,200,john101,200,john

# %%
with open(r"D:\ file.txt",'w') as file:
    print(file.write('hello'))
# Out:
# 5

# %%
with open(r"D:\ file.txt",'a') as file:
    # print(file.write('good to see u im damn missing darams'))
    file.write('cool')

# %%
with open(r"D:\ file.txt",'r') as file:
    # print(file.readline())
    # print(file.readlines())
    count1=file.readlines()
    print(len(count1))
# Out:
# 1

# %%
with open(r"D:\ file.txt",'r') as file:
    count=0
    for i in file:
        count+=1
    print(count)
# Out:
# 1

# %%
with open(r"D:\ file.txt",'r') as file:
    b=file.read()

words=b.split(' ')
print(len(words))
# Out:
# 8

# %%
with open(r"D:\ file.txt",'r') as file:
    file1=file.read()
if 'johncool' in file1:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
with open(r"D:\ file.txt",'r') as file:
    file2=file.read()
word=file2.replace('hello','hi')
with open(r"D:\file.txt", "w") as file:
    file.write(word)

print("Replacement done!")
# Out:
# Replacement done!
